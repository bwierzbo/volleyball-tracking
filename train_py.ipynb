# %% [markdown]
# <a href="https://colab.research.google.com/github/bwierzbo/volleyball-tracking/blob/main/train_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disable warning
import warnings
warnings.filterwarnings('ignore')


import numpy as np
import pandas as pd 
import tensorflow

from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from keras.utils import load_img
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import random
import os

# %%
filenames = os.listdir("../VolleyballTracking/coloroutpath/")
categories = []

for filename in filenames:
    category = filename.split('-')[0]
    if category == 'notball':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-b8dee46880ff> in <module>
# ----> 1 filenames = os.listdir("../VolleyballTracking/coloroutpath/")
#       2 categories = []
#       3
#       4 for filename in filenames:
#       5     category = filename.split('-')[0]
#
# FileNotFoundError: [Errno 2] No such file or directory: '../VolleyballTracking/coloroutpath/'
